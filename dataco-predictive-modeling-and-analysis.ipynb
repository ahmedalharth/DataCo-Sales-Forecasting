# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#About-The-Project" data-toc-modified-id="About-The-Project-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>About The Project</a></span><ul class="toc-item"><li><span><a href="#Objective" data-toc-modified-id="Objective-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Objective</a></span><ul class="toc-item"><li><span><a href="#Sales-Forecasting-Using-Machine-Learning" data-toc-modified-id="Sales-Forecasting-Using-Machine-Learning-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Sales Forecasting Using Machine Learning</a></span></li><li><span><a href="#Questions" data-toc-modified-id="Questions-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Questions</a></span></li></ul></li></ul></li><li><span><a href="#Data-Description" data-toc-modified-id="Data-Description-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data Description</a></span></li><li><span><a href="#Project-Steps" data-toc-modified-id="Project-Steps-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Project Steps</a></span></li><li><span><a href="#Functions-for-letter-use" data-toc-modified-id="Functions-for-letter-use-4"><span class="toc-item-num">4&nbsp;&nbsp;</span><strong>Functions for letter use</strong></a></span></li><li><span><a href="#Importing-Libraries" data-toc-modified-id="Importing-Libraries-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Importing Libraries</a></span></li><li><span><a href="#Data-Mining-and-Preprocessing" data-toc-modified-id="Data-Mining-and-Preprocessing-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Data Mining and Preprocessing</a></span><ul class="toc-item"><li><span><a href="#Data-Cleansing-and-Descriptive-stataistics" data-toc-modified-id="Data-Cleansing-and-Descriptive-stataistics-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Data Cleansing and Descriptive stataistics</a></span><ul class="toc-item"><li><span><a href="#The-following-variables-are-not-needed-form-the-describtion;" data-toc-modified-id="The-following-variables-are-not-needed-form-the-describtion;-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>The following variables are not needed form the describtion;</a></span></li><li><span><a href="#Charactrizetion-of-the-Data-to-better-understanding" data-toc-modified-id="Charactrizetion-of-the-Data-to-better-understanding-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>Charactrizetion of the Data to better understanding</a></span></li></ul></li><li><span><a href="#Customers-and-Sales-informations" data-toc-modified-id="Customers-and-Sales-informations-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Customers and Sales informations</a></span></li><li><span><a href="#Products-Informations" data-toc-modified-id="Products-Informations-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Products Informations</a></span></li><li><span><a href="#Orders-and-Shippings" data-toc-modified-id="Orders-and-Shippings-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Orders and Shippings</a></span></li><li><span><a href="#Missing-Values-&amp;-Duplication" data-toc-modified-id="Missing-Values-&amp;-Duplication-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Missing Values &amp; Duplication</a></span></li><li><span><a href="#Summary" data-toc-modified-id="Summary-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Summary</a></span></li></ul></li><li><span><a href="#2.-Explorntory-Data-Analysis" data-toc-modified-id="2.-Explorntory-Data-Analysis-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>2. Explorntory Data Analysis</a></span><ul class="toc-item"><li><span><a href="#Uinvariate-analysis" data-toc-modified-id="Uinvariate-analysis-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Uinvariate analysis</a></span><ul class="toc-item"><li><span><a href="#Features-Distributions" data-toc-modified-id="Features-Distributions-7.1.1"><span class="toc-item-num">7.1.1&nbsp;&nbsp;</span>Features Distributions</a></span></li><li><span><a href="#Outliers-analysis" data-toc-modified-id="Outliers-analysis-7.1.2"><span class="toc-item-num">7.1.2&nbsp;&nbsp;</span>Outliers analysis</a></span></li><li><span><a href="#Mutul-Information" data-toc-modified-id="Mutul-Information-7.1.3"><span class="toc-item-num">7.1.3&nbsp;&nbsp;</span>Mutul Information</a></span></li></ul></li><li><span><a href="#Bivariate-analysis" data-toc-modified-id="Bivariate-analysis-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Bivariate analysis</a></span><ul class="toc-item"><li><span><a href="#Pivot-tables" data-toc-modified-id="Pivot-tables-7.2.1"><span class="toc-item-num">7.2.1&nbsp;&nbsp;</span>Pivot tables</a></span></li><li><span><a href="#Products-and-Sales" data-toc-modified-id="Products-and-Sales-7.2.2"><span class="toc-item-num">7.2.2&nbsp;&nbsp;</span>Products and Sales</a></span></li><li><span><a href="#Sales-over-time" data-toc-modified-id="Sales-over-time-7.2.3"><span class="toc-item-num">7.2.3&nbsp;&nbsp;</span>Sales over time</a></span></li><li><span><a href="#Correlation-Analysis" data-toc-modified-id="Correlation-Analysis-7.2.4"><span class="toc-item-num">7.2.4&nbsp;&nbsp;</span>Correlation Analysis</a></span></li><li><span><a href="#Cramer's-V" data-toc-modified-id="Cramer's-V-7.2.5"><span class="toc-item-num">7.2.5&nbsp;&nbsp;</span>Cramer's V</a></span></li></ul></li><li><span><a href="#Features-Engeneering-and-Selection" data-toc-modified-id="Features-Engeneering-and-Selection-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Features Engeneering and Selection</a></span><ul class="toc-item"><li><span><a href="#Split-the-Data" data-toc-modified-id="Split-the-Data-7.3.1"><span class="toc-item-num">7.3.1&nbsp;&nbsp;</span>Split the Data</a></span></li><li><span><a href="#Target-Encoding" data-toc-modified-id="Target-Encoding-7.3.2"><span class="toc-item-num">7.3.2&nbsp;&nbsp;</span>Target Encoding</a></span></li></ul></li></ul></li><li><span><a href="#Modeling" data-toc-modified-id="Modeling-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Modeling</a></span><ul class="toc-item"><li><span><a href="#Models-For-Regression" data-toc-modified-id="Models-For-Regression-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Models For Regression</a></span><ul class="toc-item"><li><span><a href="#Linear-Models" data-toc-modified-id="Linear-Models-8.1.1"><span class="toc-item-num">8.1.1&nbsp;&nbsp;</span>Linear Models</a></span></li><li><span><a href="#Tree-Based-Model" data-toc-modified-id="Tree-Based-Model-8.1.2"><span class="toc-item-num">8.1.2&nbsp;&nbsp;</span>Tree Based Model</a></span></li><li><span><a href="#Ensemble-Models" data-toc-modified-id="Ensemble-Models-8.1.3"><span class="toc-item-num">8.1.3&nbsp;&nbsp;</span>Ensemble Models</a></span></li></ul></li><li><span><a href="#Preprocessing" data-toc-modified-id="Preprocessing-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Preprocessing</a></span><ul class="toc-item"><li><span><a href="#features-selection" data-toc-modified-id="features-selection-8.2.1"><span class="toc-item-num">8.2.1&nbsp;&nbsp;</span>features selection</a></span></li></ul></li><li><span><a href="#Model-Training" data-toc-modified-id="Model-Training-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Model Training</a></span></li></ul></li></ul></div>

# %% [markdown]
# # About The Project

# %% [markdown]
# **Effective inventory and sales management are essential for any company to succeed in the fast-paced, cutthroat business world of today. A key component of improving efficiency, cutting costs, and ensuring customer loyalty is accurate sales and stock level prediction. The dynamic and intricate patterns of sales and inventory data frequently confound standard forecasting methods. However, new avenues for precise and effective supply chain forecasting have been made possible by the advancement of machine learning techniques. Investigating how DataCo's Smart Supply Chain forecasts sales and inventory using machine learning models is the aim of this project.**

# %% [markdown]
# ## Objective
#
# ### Sales Forecasting Using Machine Learning
#
#
# **The goal of this project is to develop a predictive model that forecasts future sales based on historical data, customer demographics, and order details. By leveraging data science techniques, the project aims to identify patterns and trends that can help optimize inventory management, enhance marketing strategies, and improve overall business performance**

# %% [markdown]
# ### Questions
#
# **What are the factors that influnce sales of the company?**

# %% [markdown]
# # Data Description
#
# A DataSet of Supply Chains used by the company DataCo Global was used for the analysis. Dataset of Supply Chain , which allows the use of Machine Learning Algorithms.
# The dataset used for contains detailed information about transactions, shipping, customer demographics, and product details.
#
# **Data Source: Kaggle** - [DataCo Smart Supply Chain](http://https://www.kaggle.com/datasets/shashwatwork/dataco-smart-supply-chain-for-big-data-analysis)

# %% [markdown]
# # Project Steps
#
#
# > 1. Understand the Data.
# > 2. Data Mining And Processing.
# > 3. Exploratory Data Analysis.
# > 4. Data Modeling.
# > 5. Restut Interpretaion.
# > 6. Mode Deployment.

# %% [markdown]
# # **Functions for letter use**

# %%
def value_counts_with_percentage(df, columns):
    """
    Calculate and display value counts with percentages for specified columns.

    Parameters:
    df (pd.DataFrame): The DataFrame containing the data.
    columns (list): List of column names to compute value counts and percentages.

    Returns:
    dict: A dictionary of DataFrames for each column's counts and percentages.
    """
    results = {}
    
    for column in columns:
        if column in df.columns:
            value_counts = df[column].value_counts()
            percentages = (value_counts / value_counts.sum()) * 100
            
            result = pd.DataFrame({
                'Count(N)': value_counts,
                'Percentage(%)': percentages
            })
            
            results[column] = result
            print(f"\nValue Counts for '{column}':")
            print(result)
        else:
            print(f"\nColumn '{column}' not found in DataFrame.")

# %%
# Function to detect outliers using IQR
def detect_Xor_drop_outliers(df, columns , drop = False):
    
    outliers = pd.DataFrame()
    
    for col in columns:
        
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 3 * IQR
        upper_bound = Q3 + 3 * IQR
        
        outliers[col] = df[(df[col] < lower_bound) | (df[col] > upper_bound)][col]
        
    if drop == True:
        
        df_clean = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
        
        return df_clean
    
    else:
        
        return outliers

# %%
# Pivot tables function
def pivot_tables(data ,index):
    
    result = pd.pivot_table(data ,

                                  values = ['order_id','order_item_product_price',
                                            'order_item_quantity','sales','order_item_discount',
                                            'order_item_discount_rate','benefit_per_order',
                                            'order_item_profit_ratio','sales_per_customer'],

                                  index = [index],

                                  aggfunc = {"order_id":'count',
                                            "sales":'sum',
                                            'order_item_quantity':'sum',
                                            'order_item_discount':'sum',
                                            'order_item_discount_rate':'sum',
                                            'order_item_profit_ratio':'sum',
                                            'sales_per_customer':'sum',
                                            'benefit_per_order':'sum'},

                                  fill_value = 0
                                )
    return result

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency

# Function to calculate Cramér's V
def cramers_v(confusion_matrix):
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.values.sum()  # Ensure n is a scalar
    r, k = confusion_matrix.shape

    if n == 0:  # Avoid division by zero
        return 0

    phi2 = chi2 / n
    phi2corr = max(0, phi2 - ((k - 1) * (r - 1)) / (n - 1) if n > 1 else phi2)
    r_corr = r - ((r - 1) ** 2) / (n - 1) if n > 1 else r
    k_corr = k - ((k - 1) ** 2) / (n - 1) if n > 1 else k

    return np.sqrt(phi2corr / min((k_corr - 1), (r_corr - 1)) if min(k_corr, r_corr) > 1 else 1)


# Function to calculate pairwise Cramér's V for all categorical variables
def calculate_cramers_v_matrix(df, categorical_columns):
    matrix = pd.DataFrame(np.zeros((len(categorical_columns), len(categorical_columns))),
                          index=categorical_columns, columns=categorical_columns)
    
    for col1 in categorical_columns:
        for col2 in categorical_columns:
            if col1 == col2:
                matrix.loc[col1, col2] = 1.0
            else:
                confusion_matrix = pd.crosstab(df[col1], df[col2])
                matrix.loc[col1, col2] = cramers_v(confusion_matrix)
    
    return matrix

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt


pd.plotting.register_matplotlib_converters()
# %matplotlib inline
from IPython.display import display
from itertools import combinations
from collections import Counter


import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor


# pre_preprocessing
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, LabelEncoder , StandardScaler , MinMaxScaler , RobustScaler


# Resampling
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

# Valdiation
from sklearn.model_selection import StratifiedShuffleSplit , StratifiedKFold , GroupKFold
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.model_selection import KFold

# Modeling
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor


# Metrics
from sklearn.metrics import r2_score , median_absolute_error , mean_squared_error, mean_absolute_error

import warnings
warnings.filterwarnings('ignore')

#display all column of df 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None) 
# to format the scientific presntastion of numbers 
pd.options.display.float_format = '{:.2f}'.format

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/tokenized_access_logs.csv
# /kaggle/input/DataCoSupplyChainDataset.csv
# /kaggle/input/DescriptionDataCoSupplyChain.csv

# %%
# df = pd.read_csv("/kaggle/input/DataCoSupplyChainDataset.csv")
df = pd.read_csv("/kaggle/input/DataCoSupplyChainDataset.csv", encoding="latin1")

# %% [markdown]
# ___

# %% [markdown]
# # Data Mining and Preprocessing

# %% [markdown]
# ## Data Cleansing and Descriptive stataistics

# %%
# Varibales descriptions
# df_des.T

# %% [markdown]
# ###  The following variables are not needed form the describtion;
#
# * Customer Email, Customer Fname (12), Lname , Latitude/Longitude (22, 23) Customer Password (15) – Are useful for personalization but raises privacy concerns; ensure data protection compliance, Thus not needed.
# * Product Image (46) – Visual appeal is helpful but may not be essential for core data analysis unless working on e-commerce interfaces.
# * Customer Zipcode (19), Customer Street (18) – If city and state are already available, detailed street-level data may be overkill unless hyper-local analysis is required.
# * Department Id/Name (20, 21) – Only useful if the business operates across multiple departments with distinct sales patterns.
#
# Thus, drop it from the first while

# %%
df.drop([
        "Customer Email",         
        "Customer Fname",         
        "Customer Lname",         
        "Customer Password",      
        "Latitude",               
        "Longitude",              
        "Product Image" ,
        "Customer Zipcode",        
        "Customer Street",         
        "Department Id",           
        "Department Name"],
         axis=1,
        inplace = True)

# %% [markdown]
# ___

# %%
display(df.head())
print('* Data Shape =>', df.shape)
print("* Number of Numerical features =>",len(df.select_dtypes(exclude="O").columns.to_list()))
print("* Number of categorical features =>",len(df.select_dtypes(include="O").columns.to_list()))
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0              91.25              314.64  Advance shipping
# 1            -249.09              311.36     Late delivery
# 2            -247.78              309.72  Shipping on time
# 3              22.86              304.81  Advance shipping
# 4             134.21              298.25  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  \
# 0                   0           73  Sporting Goods        Caguas
# ...

# %%
# Edite columns Names
df.columns = df.columns.str.replace(' ', '_').str.lower()

# %%
# Information about the features
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 42 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   type                           180519 non-null  object
#  1   days_for_shipping_(real)       180519 non-null  int64
#  2   days_for_shipment_(scheduled)  180519 non-null  int64
#  3   benefit_per_order              180519 non-null  float64
#  4   sales_per_customer             180519 non-null  float64
#  5   delivery_status                180519 non-null  object
#  6   late_delivery_risk             180519 non-null  int64
#  7   category_id                    180519 non-null  int64
#  8   category_name                  180519 non-null  object
#  9   customer_city                  180519 non-null  object
#  10  customer_country               180519 non-null  object
#  11  customer_id                    180519 non-null  int64
# ...

# %% [markdown]
# > * **product_status**: which is the status of the product stock :If it is 1 not available , 0 the product is available.
# > * **late_delivery_risk**: which also categorical
# > * **product_description**: Null column

# %%
df[['late_delivery_risk','product_status']]= df[['late_delivery_risk','product_status']].astype("object")

# %%
# Null Column 
df.drop("product_description", axis=1, inplace=True)

# %% [markdown]
# ___

# %% [markdown]
# ### Charactrizetion of the Data to better understanding

# %%
# All Ids in the data to object type
Ids = [i for i in df.columns if 'id' in i]
df[Ids] = df[Ids].astype("O")

# %%
customer_and_sales = [i for i in df.columns if ('sales' in i) or ("customer" in i)]
# customer_and_sales

# %%
order_shippen_delivery = [i for i in df.columns if ("order" in i) or ("delivery_status" in i) or ("market" in i) 
        or ("late_delivery_risk" in i) or ('type' in i) or ('ship' in i)] 

order_shippen_delivery.remove('order_customer_id')
# order_shippen_delivery

# %%
products = [i for i in df.columns if ("category" in i) or ( "product" in i)]
products.remove('order_item_product_price')
# products

# %%
len(df.columns) == len(products+order_shippen_delivery+customer_and_sales)
# Out:
# True

# %% [markdown]
# ___

# %% [markdown]
# ## Customers and Sales informations

# %%
# describtion for Numerical features
df[customer_and_sales].describe()
# Out:
#        sales_per_customer     sales
# count           180519.00 180519.00
# mean               183.11    203.77
# std                120.04    132.27
# min                  7.49      9.99
# 25%                104.38    119.98
# 50%                163.99    199.92
# 75%                247.40    299.95
# max               1939.99   1999.99

# %%
# describtion for the Cateogrical features
df[customer_and_sales].describe(include='O')
# Out:
#        customer_city customer_country  customer_id customer_segment  \
# count         180519           180519       180519           180519
# unique           563                2        20652                3
# top           Caguas          EE. UU.         5654         Consumer
# freq           66770           111146           47            93504
#
#        customer_state  order_customer_id
# count          180519             180519
# unique             46              20652
# top                PR               5654
# freq            69373                 47

# %% [markdown]
# > **customer_id** and **order_customer_id** were the same and just one is needed

# %%
# Cheeck for duplicat ids
df['order_customer_id'].equals(df['customer_id'])
# Out:
# True

# %%
df.drop('order_customer_id',axis=1,inplace=True)
customer_and_sales.remove('order_customer_id')

# %%
# Number of custemr cties stats and type of Seqments for each Country
df.groupby("customer_country")[["customer_city",'customer_state','customer_segment']].nunique().reset_index()
# Out:
#   customer_country  customer_city  customer_state  customer_segment
# 0          EE. UU.            541              45                 3
# 1      Puerto Rico             22               1                 3

# %% [markdown]
# > The table above shows that all most **(96%)** of the custumres are from the United State cities.

# %%
# The 3 customer segment
value_counts_with_percentage(df, ['customer_segment'])
# Out:
# Value Counts for 'customer_segment':
#                   Count(N)  Percentage(%)
# customer_segment
# Consumer             93504          51.80
# Corporate            54789          30.35
# Home Office          32226          17.85

# %% [markdown]
# > **The table above sohws that (51%) of customers are *Consumers*, followed by (30%) *Croporates*.**
# > > **Q1** For *Consumer* and *Home Office* There is a hypothesis of high risk sales that should be addressd latter in the analysis.

# %% [markdown]
# ___

# %% [markdown]
# ## Products Informations

# %%
# Numerical variables
df[products+['order_item_product_price']].describe()
# Out:
#        product_price  order_item_product_price
# count      180519.00                 180519.00
# mean          141.23                    141.23
# std           139.73                    139.73
# min             9.99                      9.99
# 25%            50.00                     50.00
# 50%            59.99                     59.99
# 75%           199.99                    199.99
# max          1999.99                   1999.99

# %% [markdown]
#  > Dupliction in  **order_item_product_price** and **product_price**.

# %%
# Check for rudanadent features
df['product_price'].equals(df['order_item_product_price'])
# Out:
# True

# %%
df.drop('product_price',axis=1,inplace= True)
# update the list
products.remove('product_price')

# %%
# Translate to object data type
df[['product_status']] = df[['product_status']].astype("O")

# %%
df[products].describe(include='O')
# Out:
#         category_id category_name  product_card_id  product_category_id  \
# count        180519        180519           180519               180519
# unique           51            50              118                   51
# top              17        Cleats              365                   17
# freq          24551         24551            24515                24551
#
#                             product_name  product_status
# count                             180519          180519
# unique                               118               1
# top     Perfect Fitness Perfect Rip Deck               0
# freq                               24515          180519

# %% [markdown]
# > **proudact_name**
# > * The table above shows that company provides **(118)** diferent proudcts.
#
# > **product_status**
# >  * have one uniqe value which not useful and should be droped.
#
# > **cateogry_name** has **(50)** unique values along with **(51)** unique values for **cateogry_id**, and **proudct_categry_id**. Although just one is needed.

# %%
# check for duplicat ides
df['category_id'].equals(df['product_category_id'])
# Out:
# True

# %%
df.drop(["product_status",'category_id','category_name'],axis=1, inplace=True)

# %%
# update the list
products.remove('product_status')
products.remove('category_id')
products.remove('category_name')

# %%
value_counts_with_percentage(df,['product_name'])
# Out:
# Value Counts for 'product_name':
#                                                Count(N)  Percentage(%)
# product_name
# Perfect Fitness Perfect Rip Deck                  24515          13.58
# Nike Men's CJ Elite 2 TD Football Cleat           22246          12.32
# Nike Men's Dri-FIT Victory Golf Polo              21035          11.65
# O'Brien Men's Neoprene Life Vest                  19298          10.69
# Field & Stream Sportsman 16 Gun Fire Safe         17325           9.60
# Pelican Sunstream 100 Kayak                       15500           8.59
# Diamondback Women's Serene Classic Comfort Bi     13729           7.61
# Nike Men's Free 5.0+ Running Shoe                 12169           6.74
# Under Armour Girls' Toddler Spine Surge Runni     10617           5.88
# Fighting video games                                838           0.46
# Children's heaters                                  652           0.36
# Summer dresses                                      650           0.36
# ...

# %% [markdown]
# ___

# %% [markdown]
# ## Orders and Shippings

# %%
# Description for the Numerical features
df[order_shippen_delivery + ['sales_per_customer']].describe().T
# Out:
#                                   count     mean      std      min      25%  \
# days_for_shipping_(real)      180519.00     3.50     1.62     0.00     2.00
# days_for_shipment_(scheduled) 180519.00     2.93     1.37     0.00     2.00
# benefit_per_order             180519.00    21.97   104.43 -4274.98     7.00
# order_item_discount           180519.00    20.66    21.80     0.00     5.40
# order_item_discount_rate      180519.00     0.10     0.07     0.00     0.04
# order_item_product_price      180519.00   141.23   139.73     9.99    50.00
# order_item_profit_ratio       180519.00     0.12     0.47    -2.75     0.08
# order_item_quantity           180519.00     2.13     1.45     1.00     1.00
# order_item_total              180519.00   183.11   120.04     7.49   104.38
# order_profit_per_order        180519.00    21.97   104.43 -4274.98     7.00
# order_zipcode                  24840.00 55426.13 31919.28  1040.00 23464.00
# ...

# %% [markdown]
# **what do you see?**
#
# > Duplicated columns which are: ("**benefit_per_order**" & "**order_profit_per_order**".) and ("**order_item_total**" & "**sales_per_customer**")
# >
# > **NOTES**
# > * Discount Rate = (Order Item Discount / Order Item Product Price) × 100.
# > * Order Item Profit Ratio = (Profit / Cost) × 100.
# > * Order Item Total = Order Item Product Price - Order Item Discount.
# > * Cost = ?
# >
# > This information in the data may lead to multicollinearity that shoud be invstegated letter.

# %%
df['order_item_total'].equals(df['sales_per_customer'])
# Out:
# True

# %%
df['order_profit_per_order'].equals(df['benefit_per_order'])
# Out:
# True

# %%
# Drop the redundant features
df.drop('order_profit_per_order',axis=1,inplace=True)
df.drop('order_item_total',axis=1,inplace=True)
order_shippen_delivery.remove('order_profit_per_order')
order_shippen_delivery.remove('order_item_total')

# %%
# Cateogrical features in the orders and shipping
df[order_shippen_delivery].describe(include='O').T
# Out:
#                              count  unique               top    freq
# type                        180519       4             DEBIT   69295
# delivery_status             180519       4     Late delivery   98977
# late_delivery_risk          180519       2                 1   98977
# market                      180519       5             LATAM   51594
# order_city                  180519    3597     Santo Domingo    2211
# order_country               180519     164    Estados Unidos   24840
# order_date_(dateorders)     180519   65752  12/14/2016 12:29       5
# order_id                    180519   65752             48880       5
# order_item_cardprod_id      180519     118               365   24515
# order_item_id               180519  180519            180517       1
# order_region                180519      23   Central America   28341
# order_state                 180519    1089        Inglaterra    6722
# order_status                180519       9          COMPLETE   59491
# ...

# %% [markdown]
# > * ***shipping date (DateOrders)*** & ***order date (DateOrders)*** were time based features, so they were transformd.

# %%
# Date time Features
df['shipping_date_(dateorders)']= pd.to_datetime(df['shipping_date_(dateorders)'])
df['order_date_(dateorders)'] = pd.to_datetime(df['order_date_(dateorders)'])

# %%
value_counts_with_percentage(df,['type','shipping_mode','delivery_status',
                                 'late_delivery_risk',"market",
                                 'order_status','order_region'])
# Out:
# Value Counts for 'type':
#           Count(N)  Percentage(%)
# type
# DEBIT        69295          38.39
# TRANSFER     49883          27.63
# PAYMENT      41725          23.11
# CASH         19616          10.87
#
# Value Counts for 'shipping_mode':
#                 Count(N)  Percentage(%)
# shipping_mode
# Standard Class    107752          59.69
# Second Class       35216          19.51
# First Class        27814          15.41
# Same Day            9737           5.39
#
# Value Counts for 'delivery_status':
#                    Count(N)  Percentage(%)
# delivery_status
# Late delivery         98977          54.83
# Advance shipping      41592          23.04
# Shipping on time      32196          17.84
# Shipping canceled      7754           4.30
#
# Value Counts for 'late_delivery_risk':
#                     Count(N)  Percentage(%)
# late_delivery_risk
# 1                      98977          54.83
# 0                      81542          45.17
#
# Value Counts for 'market':
# ...

# %% [markdown]
# > **Type of transction**
# > * (38.39%) of tracsion were DEBIT Tracks individual spending habits and withdrawals.
#
# >**Shippings Mode**
# > * The table above shows that **(57%)** of shippings modes was "Standar Class" which provide that most of the orders takes **long time delvery from 5 to 7 dayes.**
#
# >**Delivery Status**
# > * Ther is a problem of Late deliveriy status that repersent **(54.83%)** of the total deliveriy status, and low precegte of Shipping on time **(17.84%)** that show be addressed in the analysis.
#
# > **late_delivery_risk**
# > * Most of the orders **(54.83%)** were late in delivery which is a problem that my influce the salse of the company.
#
#
# >**Order Status**
# > * Also **(32%)** of orderes are completed, while ther is **(22%)** PENDING and so on as shown in the table.
#
# > **Orders Regions**
# > * Orders regions covers 23 region, where **(15.7%)** are from central America and **(15.02%)** are from Western America and so on as shown in the table.

# %% [markdown]
# ## Missing Values & Duplication

# %%
# Missing values
df.isnull().sum()
# Out:
# type                                  0
# days_for_shipping_(real)              0
# days_for_shipment_(scheduled)         0
# benefit_per_order                     0
# sales_per_customer                    0
# delivery_status                       0
# late_delivery_risk                    0
# customer_city                         0
# customer_country                      0
# customer_id                           0
# customer_segment                      0
# customer_state                        0
# market                                0
# order_city                            0
# order_country                         0
# order_date_(dateorders)               0
# order_id                              0
# order_item_cardprod_id                0
# order_item_discount                   0
# order_item_discount_rate              0
# order_item_id                         0
# order_item_product_price              0
# order_item_profit_ratio               0
# ...

# %% [markdown]
# There are a lot of Missing values in one feature, where 86% of **Order Zipcode** is missing.

# %%
df.drop('order_zipcode', axis=1, inplace=True)
# update
order_shippen_delivery.remove('order_zipcode')

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ## Summary
#
#     In this section we intrduced some descritve statistics and basic information about the data,  that involves error detection and corrections, checking for duplicats and missing values, and droping redundent and unnessery features.
#
# **This can be summarized as follow:**
# > * **Unnessery features:**
# >> ["Customer Email","Customer Fname","Customer Lname","Customer Password", "Latitude","Longitude", "Product Image" , "Customer Zipcode",'Customer Street","Department Id", "Department Name"]
# > * **Duplicat features:**
# >> **(product_price, order_item_product_price)/(category_id ,product_category_id),
#    (order_profit_per_order,benefit_per_order)/(sales_per_customer,order_item_total).**
#
# > * **Drop Missing values:** which was in "order_zipcode", since it also not usefull for analysis.

# %% [markdown]
# ___

# %% [markdown]
# # 2. Explorntory Data Analysis

# %% [markdown]
# ## Uinvariate analysis

# %%
num_feat = df.select_dtypes(exclude="O").columns.to_list()
cat_feat = df.select_dtypes(include = "O").columns.to_list()

# %% [markdown]
# ### Features Distributions

# %%
target = 'sales'

# %%
# sns.kdeplot(np.log2(df[target]),fill=True,bw_method='scott',cumulative=False,log_scale=False)

# %%
len(df[df[target] > 550])
# Out:
# 488

# %%
# figure, axis = plt.subplots(5, 3, figsize=(15, 15))
# plt.subplots_adjust(hspace=0.5, wspace=0.5)

# for i, column_name in enumerate(num_feat):
#     row = i//3
#     col = i % 3
#     bp = sns.histplot(ax=axis[row, col], y=df[column_name],palette='Set2') 
#     bp.set(xticklabels=[])

#     # Rotate labels if needed
#     for label in axis[row, col].get_xticklabels():
#         label.set_size(10)  # Adjust size of x-axis labels
#         label.set(rotation=45, ha='right')  # Rotate x-axis labels for readability
    
#     # Set title with larger font size and proper styling
#     axis[row, col].set_title(column_name.replace('_', ' ').capitalize(), fontsize=12, fontweight='bold')
    
#     # Optionally, adjust grid and background color for clarity
#     axis[row, col].grid(True, linestyle='--', alpha=0.6)  # Grid with dashed lines and transparency

# # Remove any empty subplots (if the number of features isn't divisible by 3)
# for i in range(len(num_feat), 15):  # 15 is the total number of subplots (5x3 grid)
#     figure.delaxes(axis.flatten()[i])

# # Show the plot
# plt.show()

# %% [markdown]
# ### Outliers analysis

# %%
num_feat
# Out:
# ['days_for_shipping_(real)',
#  'days_for_shipment_(scheduled)',
#  'benefit_per_order',
#  'sales_per_customer',
#  'order_date_(dateorders)',
#  'order_item_discount',
#  'order_item_discount_rate',
#  'order_item_product_price',
#  'order_item_profit_ratio',
#  'order_item_quantity',
#  'sales',
#  'shipping_date_(dateorders)']

# %%
# Boxplot for numerical features
figure, axis = plt.subplots(4, 2 ,figsize=(20, 12))
plt.subplots_adjust(hspace=0.7, wspace=0.5)

for i, column_name in enumerate([
 'benefit_per_order',
 'sales_per_customer',
 'order_item_discount',
 'order_item_discount_rate',
 'order_item_product_price',
 'order_item_profit_ratio',
 'order_item_quantity',
 'sales']):
    row = i//2
    col = i % 2
    bp = sns.boxplot(ax=axis[row, col], x=df[column_name], color= 'lightgreen')
#   # Rotate labels if needed
    for label in axis[row, col].get_xticklabels():
        label.set_size(10)  # Adjust size of x-axis labels
        label.set(rotation=45, ha='right')  # Rotate x-axis labels for readability
    
    # Set title with larger font size and proper styling
    axis[row, col].set_title(column_name.replace('_', ' ').capitalize(), fontsize=12, fontweight='bold')
    
    # Optionally, adjust grid and background color for clarity
    axis[row, col].grid(True, linestyle='--', alpha=0.6)  # Grid with dashed lines and transparency

# Remove any empty subplots (if the number of features isn't divisible by 3)
# for i in range(len(num_feat), 15):  # 15 is the total number of subplots (5x3 grid)
#     figure.delaxes(axis.flatten()[i])

# Show the plot
plt.show()

# %% [markdown]
#    **Test if the outliers are Random or not?**

# %%
# Detect outliers
columns_to_check =  df.select_dtypes(include=["int","float"]).columns.to_list()

outliers = detect_Xor_drop_outliers(df, columns_to_check, drop = False)

display(outliers.head())
display(outliers.shape)
# Out:
#     days_for_shipping_(real)  days_for_shipment_(scheduled)  \
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 15                       NaN                            NaN
# 16                       NaN                            NaN
# 34                       NaN                            NaN
#
#     benefit_per_order  sales_per_customer  order_item_discount  \
# 1             -249.09                 NaN                  NaN
# 2             -247.78                 NaN                  NaN
# 15            -259.58                 NaN                  NaN
# 16            -246.36                 NaN                  NaN
# 34            -425.58                 NaN                  NaN
#
#     order_item_discount_rate  order_item_product_price  \
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# ...

# %%
# Create a binary column indicating outlier presence
for col in outliers.columns:
    
    df[f'{col}_outlier'] = 0
    
    df.loc[outliers[col].index, f'{col}_outlier'] = 1

# %% [markdown]
# **Correlation analysis for the outliers**

# %%
# Correlation analysis between outlier columns and other variables

correlation_results = []

for col in columns_to_check:

    if f'{col}_outlier' in df.columns:
        
        for other_col in df[columns_to_check].columns:
            
            if other_col != col and '_outlier' not in other_col:

                corr = df[f'{col}_outlier'].corr(df[other_col])
                    
                correlation_results.append({
                    'feat1': f'{col}_outlier',
                    'feat2': other_col,
                    'corr': corr
                })
                
#                 df.drop([f'{col}_outlier'], axis=1 ,inplace=True)

                
correlation_results = pd.DataFrame(correlation_results)

# Display correlation results

print("\n Correlation of outlier presence with other variables:")

display(correlation_results[np.abs(correlation_results['corr'] ) >= 0.50].T)

for col in outliers.columns:
    
    df.drop(f'{col}_outlier',axis=1,inplace=True )

# for (outlier_col, var_col), corr_value in correlation_results.items():

#     print(f"{outlier_col} with {var_col}: {corr_value:.2f}")
# Out:
#  Correlation of outlier presence with other variables:
#                                      1                                 6   \
# feat1  days_for_shipping_(real)_outlier  days_for_shipping_(real)_outlier
# feat2                 benefit_per_order           order_item_profit_ratio
# corr                              -0.67                             -0.67
#
#                                           10  \
# feat1  days_for_shipment_(scheduled)_outlier
# feat2                      benefit_per_order
# corr                                   -0.67
#
#                                           15                         24  \
# feat1  days_for_shipment_(scheduled)_outlier  benefit_per_order_outlier
# feat2                order_item_profit_ratio    order_item_profit_ratio
# corr                                   -0.67                      -0.67
#
#                                29                          33  \
# feat1  sales_per_customer_outlier  sales_per_customer_outlier
# ...

# %% [markdown]
# > All Outliers have correlation with **order_item_profit_ratio**, which it not intresting for the objective.

# %%
# Drop the outliers
df = detect_Xor_drop_outliers(df, columns_to_check, drop=True)

# %%
df.shape
# Out:
# (180052, 33)

# %%
# figure, axis = plt.subplots(2, 4, figsize=(18, 9))
# plt.subplots_adjust(hspace=0.5, wspace=0.8)

# for i, column_name in enumerate(['late_delivery_risk','delivery_status','type','customer_country',
#                                  'customer_segment','market','order_status','shipping_mode']):
#     row = i//4
#     col = i % 4
#     bp = sns.countplot(ax=axis[row, col], y=df[column_name] , hue=df[column_name] ,palette='Set2') 
#     bp.set(xticklabels=[])
#     #bp.set_xticklabels(bp.get_xticklabels(), rotation=90, size = 7)
# #     axis[row, col].set_title(column_name.replace('_'," ").upper())

#     bp.set_ylabel(column_name.replace('_', ' ').capitalize(), fontsize=12)  # Set y-axis label with proper formatting
    
#     # Rotate labels for better visibility (only if necessary)
#     for label in bp.get_yaxis().get_ticklabels():
#         label.set_size(10)  # Adjust size of y-axis labels

#     # Set title with larger font size and a bit of spacing
#     axis[row, col].set_title(column_name.replace('_', ' ').capitalize(), fontsize=14, fontweight='bold')
    

# plt.show()

# %% [markdown]
# ### Mutul Information
# `The mutual information (MI) between two quantities is a measure of the extent to which knowledge of one quantity reduces uncertainty about the other.`
#
# `Values of MI Starts with 0, and in practice values above 2.0 means good information gain.`

# %%
# df_mutu = df.copy()

# df_mutu.drop(['shipping_date_(dateorders)','order_date_(dateorders)'],axis=1,inplace=True)

# %%
# for colname in df_mutu.select_dtypes("object"):
#     df_mutu[colname], _ = df_mutu[colname].factorize()

# %%
# from sklearn.feature_selection import mutual_info_regression
# def make_mi_scores(X, y, discrete_features):
#     X = X.drop('sales',axis=1)
#     mi_scores = mutual_info_regression(X, y)
#     mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
#     mi_scores = mi_scores.sort_values(ascending=False)
#     return mi_scores

# mi_scores = make_mi_scores(df_mutu, df_mutu.sales,discrete_features='auto')
# mi_scores[::3]

# %%
# def plot_mi_scores(scores):
#     scores = scores.sort_values(ascending=True)
#     width = np.arange(len(scores))
#     ticks = list(scores.index)
#     plt.barh(width, scores)
#     plt.yticks(width, ticks)
#     plt.title("Mutual Information Scores")


# plt.figure(dpi=100, figsize=(8, 5))
# plot_mi_scores(mi_scores)

# %% [markdown]
# > * **MI can help you to understand the relative potential of a feature as a predictor of the target, considered by itself.**
# >* **It's possible for a feature to be very informative when interacting with other features, but not so informative all alone. MI can't detect interactions between features.**

# %% [markdown]
# ## Bivariate analysis

# %% [markdown]
# ### Pivot tables
#
#            The following pivot tables shows the sum of salse, benefits, discounts, and the number of orders and products for each categorical feature.

# %% [markdown]
#     Loses per category

# %%
# display(pivot_tables(df[df['benefit_per_order'] < 0 ],'customer_country'))

# display(pivot_tables(df[df['benefit_per_order'] < 0 ],'market'))

# display(pivot_tables(df[df['benefit_per_order'] < 0 ],'customer_segment'))

# display(pivot_tables(df[df['benefit_per_order'] < 0 ],'late_delivery_risk'))

# display(pivot_tables(df[df['benefit_per_order'] < 0 ],'delivery_status'))

# display(pivot_tables(df[df['benefit_per_order'] < 0 ],'order_status'))

# display(pivot_tables(df[df['benefit_per_order'] < 0 ],'type'))

# %% [markdown]
#     Total Losese

# %%
# # Total losses
# total_losess = df[df['benefit_per_order'] < 0].groupby('order_id')['benefit_per_order'].sum()

# print('Total losess =>', total_losess.sum())

# %% [markdown]
# ### Products and Sales

# %%
# product_df = pivot_tables(df,'product_name')

# %%
# product_df.sort_values(by='order_item_quantity',ascending=False)[0:10].T

# %%
# px.bar(product_df.sort_values(by='order_item_quantity',ascending=False)[0:20]
#        ,x='order_item_quantity',
#        title='Number of Tope Ordered Products')

# %%
# px.bar(product_df.sort_values(by='order_id',ascending=False)[0:20],x='order_id',title='Number of Orders')

# %%
# px.bar(product_df.sort_values(by='order_item_discount',ascending=False)[0:-20],x='order_item_discount',title="Discount Rate Per Product")

# %%
# px.bar(product_df.sort_values(by='benefit_per_order',ascending=True)[0:-20],x='benefit_per_order',title="Products Brofite and Loss")

# %%
# products_losses = pivot_tables(df[df['benefit_per_order'] < 0 ], 'product_name')

# %%
# px.bar(products_losses.sort_values(by='benefit_per_order',ascending=True)[0:-20],x='benefit_per_order',title="Products Brofite and Loss")

# %%
# products_losses.sort_values(by='order_id',ascending=False).T

# %% [markdown]
# ### Sales over time

# %%
df = df.sort_values('order_date_(dateorders)').reset_index(drop=True)

# %%
for feat in ['shipping_date_(dateorders)','order_date_(dateorders)']:
    df[f'Month_{feat}'] = df[feat].dt.month
    df[f'Year_{feat}'] = df[feat].dt.year
    df.drop(feat, inplace=True , axis=1)

# %%
# plt.figure(figsize=(16, 6))
# plt.subplots_adjust(hspace=0.3, wspace=0.3)


# plt.subplot(2, 3, 1)
# sns.pointplot(df, x='days_for_shipping_(real)',
#               y='sales', estimator='sum')

# plt.subplot(2, 3, 2)
# sns.pointplot(df, x='Year_shipping_date_(dateorders)',
#               y='sales', estimator='sum')

# plt.subplot(2, 3, 3)
# sns.pointplot(df, x='Year_order_date_(dateorders)',
#               y='sales', estimator='sum')


# plt.subplot(2, 3, 4)
# sns.pointplot(df, x='Year_shipping_date_(dateorders)',
#               y='order_id', estimator='sum')


# plt.subplot(2, 3, 5)
# sns.pointplot(df, x='Year_order_date_(dateorders)',
#               y='order_item_quantity', estimator='sum')

# plt.subplot(2, 3, 6)
# sns.pointplot(df, x='Year_order_date_(dateorders)',
#               y='customer_id', estimator='sum')

# plt.show()

# %%
# plt.figure(figsize=(16, 6))
# plt.subplots_adjust(hspace=0.3, wspace=0.3)


# plt.subplot(2, 3, 1)
# sns.pointplot(df, x='days_for_shipping_(real)',
#               y='sales', estimator='sum')

# plt.subplot(2, 3, 2)
# sns.pointplot(df, x='Month_order_date_(dateorders)',
#               y='sales', estimator='sum')

# plt.subplot(2, 3, 3)
# sns.pointplot(df, x='Month_order_date_(dateorders)',
#               y='sales', estimator='sum')


# plt.subplot(2, 3, 4)
# sns.pointplot(df, x='Month_order_date_(dateorders)',
#               y='order_id', estimator='sum')


# plt.subplot(2, 3, 5)
# sns.pointplot(df, x='Month_order_date_(dateorders)',
#               y='order_item_quantity', estimator='sum')

# plt.subplot(2, 3, 6)
# sns.pointplot(df, x='Month_order_date_(dateorders)',
#               y='customer_id', estimator='sum')

# plt.show()

# %% [markdown]
# ### Correlation Analysis

# %%
# Calculate the correlation matrix
corr = df.select_dtypes(exclude="O").corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(18, 18))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', cbar=True, linewidths=0.8, square=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Drop redundent features that not contribute to target
df.drop(['Month_shipping_date_(dateorders)','Year_shipping_date_(dateorders)','sales_per_customer'], axis=1 , inplace=True)

# %% [markdown]
# ### Cramer's V

# %% [markdown]
# `Cramér’s V is an effect size measurement for the chi-square test of independence. It measures how strongly two categorical fields are associated.`

# %%
# categorical_columns = ['type','delivery_status', 'order_region','order_country','customer_state',
#                        'customer_city','order_item_cardprod_id','product_name','customer_country',
#                        'customer_segment', 'market','shipping_mode','late_delivery_risk',
#                        'order_city','order_state','product_card_id']


# # Calculate Cramér's V matrix
# cramers_v_matrix = calculate_cramers_v_matrix(df, categorical_columns)

# # Plot the heatmap
# plt.figure(figsize=(18, 18))
# sns.heatmap(cramers_v_matrix, annot=True, cmap="coolwarm", cbar=True)
# plt.title("Cramér's V Heatmap of Categorical Variables")
# plt.show()

# %% [markdown]
# #### **Redundent features needs drop**
# > The heat map shows that **type** and **order status** are the same so drop "order_status"
#
# > **Market** and **order_region**, **order_country**, **order_state**, and **order_city** so drop the order info.
#
# > **customer_country** and **customer_state**, **customer_city**.
#
# > **product_name** and **order_item_cardprod_id** and **product_card_id**
#
# > Also **delivrry_status** and **late_delivery_status** are the same so drop one.

# %%
df.drop(['late_delivery_risk','order_status','order_region',
         'order_country',"order_city",'customer_city','customer_state',
         'order_item_cardprod_id','product_card_id','order_state'], axis=1 ,inplace=True)

# %%
df_clean = df.copy()

# %%
# df.to_csv("Clean_data.csv",index=False)

# %% [markdown]
# ## Features Engeneering

# %% [markdown]
# ### Split the Data

# %%
train , test , y_train , y_test = train_test_split(df_clean.drop('sales',axis=1),df_clean.sales ,
                                                   test_size=0.30, shuffle=True,random_state=45)

# %%
train.shape,test.shape
# Out:
# ((126036, 21), (54016, 21))

# %%
# The delay in orders
for df in [train,test]:
    
    df['DelayOrdered'] = df['days_for_shipment_(scheduled)'] - df['days_for_shipping_(real)']
    df.drop(['days_for_shipment_(scheduled)','days_for_shipping_(real)'], axis=1, inplace=True)



train['DiscountPerProduct'] = train['product_name'].map(dict(train.groupby('product_name')['order_item_discount'].max()))
test['DiscountPerProduct'] = test['product_name'].map(dict(test.groupby('product_name')['order_item_discount'].max()))


train['DenefitPerProduct'] = train['product_name'].map(dict(train.groupby('product_name')['benefit_per_order'].mean()))
test['DenefitPerProduct'] = test['product_name'].map(dict(test.groupby('product_name')['benefit_per_order'].mean()))


train['TotalDiscountPerProduct'] = train['product_name'].map(dict(train.groupby('product_name')['order_item_discount'].var()))
test['TotalDiscountPerProduct'] = test['product_name'].map(dict(test.groupby('product_name')['order_item_discount'].var()))


# Example 2: Compute the standard deviation of discounts per product
train['MaxDiscountPerOrder'] = train['order_item_id'].map(dict(train.groupby('order_item_id')['order_item_discount'].max()))
test['MaxDiscountPerOrder'] = test['order_item_id'].map(dict(test.groupby('order_item_id')['order_item_discount'].max()))

# %%
train.drop(['order_item_discount_rate','order_item_profit_ratio'],axis=1,inplace=True)
test.drop(['order_item_discount_rate','order_item_profit_ratio'],axis=1,inplace=True)

# %%
train.drop(['product_category_id','customer_id','order_item_id','order_id'],axis=1,inplace=True)
test.drop(['product_category_id','customer_id','order_item_id','order_id'],axis=1,inplace=True)

# %% [markdown]
# ### Target Encoding
#
# `Target encoding is a feature engineering technique used to handle categorical variables by encoding them based on the target variable. Instead of assigning arbitrary numerical values to categories (like in label encoding) or creating additional features (like in one-hot encoding), target encoding uses the mean of the target variable for each category as the encoded value.`

# %%
colms = ['product_name']
from category_encoders import TargetEncoder
Te = TargetEncoder()
for col in colms:
    train[f"{col}_mean"] = Te.fit_transform(train[f"{col}"], y_train)
    test[f"{col}_mean"] = Te.transform(test[f"{col}"])
    
    train.drop(col , axis=1, inplace=True)
    test.drop(col , axis=1, inplace=True)

# %%
train['product_name_mean'].corr(y_train)
# Out:
# 0.8370288689946936

# %%
cat = train.select_dtypes(include="O").columns.to_list()
num = train.select_dtypes(exclude='O').columns.to_list()

# %% [markdown]
# # Modeling
#     In order to find the best model for the problem we will choose among different models, the choice depends on several factore and the deployment is one of them !

# %% [markdown]
# ## Models For Regression

# %% [markdown]
# ### Linear Models
#
# 1. Linear Reggression(OLS)
# 2. Ridge Reggression(L1 norm)
# 3. Lasso Reggression(L2 norm)
# 4. Elistic Net

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import RobustScaler, OneHotEncoder,PolynomialFeatures
from imblearn.pipeline import Pipeline

Linear_models = {
    
    "Linear Regression" : LinearRegression(),
    "Rideg" : Ridge(),
    "Lasso" : Lasso(),
    "ElasticNet": ElasticNet()
}

Linear_processer = ColumnTransformer(
    
    
    transformers = [ 
    
    
        ('num', Pipeline(steps=[ ('scaler', StandardScaler())]), num),
    
        ('cat',Pipeline(steps=[('one_hot',OneHotEncoder(drop='first'))]),cat)
        
    
                                                                                ])

# Evaluate Each Model
for name, model in Linear_models.items():
    
    # Create Pipeline
    
    pipeline = Pipeline(steps=[
        
        ("preprocessor", Linear_processer),

        ("model", model)
    ])
    
    # Cross-Validation
    scores = cross_val_score(pipeline, train, y_train, cv=5, scoring="neg_mean_squared_error")
    
    scores2 = cross_val_score(pipeline, train, y_train, cv=5, scoring="neg_mean_absolute_error")
    
    scores3 = cross_val_score(pipeline, train, y_train, cv=5, scoring="r2")
    
    rmse_scores = np.sqrt(-scores)
    
    MAE_scores = np.sqrt(-scores2)
    
    R2_score = np.mean(scores3)
    

    print(f"Model: {name}")
    print(f"Cross-Validation RMSE: {rmse_scores.mean():.2f} (+/- {rmse_scores.std():.2f})")
    
    print(f"Cross-Validation MAE: {MAE_scores.mean():.2f} (+/- {MAE_scores.std():.2f})")
    
    print(f"Cross-Validation R2_score : {R2_score:.3f}\n")
# Out:
# Model: Linear Regression
# Cross-Validation RMSE: 28.02 (+/- 0.20)
# Cross-Validation MAE: 4.40 (+/- 0.01)
# Cross-Validation R2_score : 0.940
#
# Model: Rideg
# Cross-Validation RMSE: 28.02 (+/- 0.20)
# Cross-Validation MAE: 4.40 (+/- 0.01)
# Cross-Validation R2_score : 0.940
#
# Model: Lasso
# Cross-Validation RMSE: 28.23 (+/- 0.21)
# Cross-Validation MAE: 4.40 (+/- 0.01)
# Cross-Validation R2_score : 0.939
#
# Model: ElasticNet
# Cross-Validation RMSE: 44.65 (+/- 0.23)
# Cross-Validation MAE: 5.77 (+/- 0.02)
# Cross-Validation R2_score : 0.848

# %% [markdown]
# ### Tree Based Model
#
# 1. Decision Tree
# 2. Gradint Boosting
#
#         I's Known that most of the tree models were likely to overfit without any tunnig so here we adjust some parameters for meaningful results

# %%
from sklearn.ensemble import RandomForestRegressor,HistGradientBoostingRegressor,StackingRegressor,ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor


tree_models = {
    
    "LightGBM": LGBMRegressor(n_estimators = 200, random_state = 45, learning_rate = 0.01 ),
    
    "Decision Tree": DecisionTreeRegressor(random_state=45,max_depth=5)
    
}

tree_processer = ColumnTransformer(transformers=[
    
    
        ('num', Pipeline(steps=[ ('scaler', StandardScaler())]), num),
    
        ('cat',Pipeline(steps=[('one_hot',OneHotEncoder(drop='first'))]),cat) ])

# Evaluate Each Model
for name, model in tree_models.items():
    
    # Create Pipeline
    pipeline = Pipeline(steps=[
        
        ("Processre" , tree_processer ),
                
        ("model", model)
    ])
    
    # Cross-Validation
    scores = cross_val_score(pipeline, train, y_train, cv=5, scoring="neg_mean_squared_error")
    
    scores2 = cross_val_score(pipeline, train, y_train, cv=5, scoring="neg_mean_absolute_error")
    
    scores3 = cross_val_score(pipeline, train, y_train, cv=5, scoring="r2")
    
    rmse_scores = np.sqrt(-scores)
    
    MAE_scores = np.sqrt(-scores2)
    
    R2_score = np.mean(scores3)
    

    print(f"Model: {name}")
    print(f"Cross-Validation RMSE: {rmse_scores.mean():.2f} (+/- {rmse_scores.std():.2f})")
    print(f"Cross-Validation MAE: {MAE_scores.mean():.2f} (+/- {MAE_scores.std():.2f})")
    print(f"Cross-Validation R2_score : {R2_score:.3f}\n")
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006248 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1295
# [LightGBM] [Info] Number of data points in the train set: 100828, number of used features: 28
# [LightGBM] [Info] Start training from score 200.763243
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003035 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1297
# [LightGBM] [Info] Number of data points in the train set: 100829, number of used features: 28
# [LightGBM] [Info] Start training from score 200.675327
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002987 seconds.
# ...

# %% [markdown]
# ### Ensemble Models
#
# 1. Stacking

# %%
# from sklearn.ensemble import RandomForestRegressor,HistGradientBoostingRegressor,StackingRegressor
# from sklearn.svm import SVR


# estimators = [
    
#     ('lr', LinearRegression()),
#     ('lgbm',  DecisionTreeRegressor(random_state=45,max_depth=5))]

# StackModels = StackingRegressor(
    
#     estimators=estimators,
    
#     final_estimator= Lasso() 
# )

# pipeline = Pipeline(steps=[
    
#     ('preprocessor', tree_processer),
    
#     ("Model", StackModels)
# ])


# # Cross-Validation
# scores = cross_val_score(pipeline, train, y_train, cv=5, scoring="neg_mean_squared_error")
    
# scores2 = cross_val_score(pipeline, train, y_train, cv=5, scoring="neg_mean_absolute_error")
    
# scores3 = cross_val_score(pipeline, train, y_train, cv=5, scoring="r2")
    
# rmse_scores = np.sqrt(-scores)
    
# MAE_scores = np.sqrt(-scores2)
    
# R2_score = np.mean(scores3)
    

# print(f"Model: {name}")
# print(f"Cross-Validation RMSE: {rmse_scores.mean():.2f} (+/- {rmse_scores.std():.2f})")
# print(f"Cross-Validation MAE: {MAE_scores.mean():.2f} (+/- {MAE_scores.std():.2f})")
# print(f"Cross-Validation R2_score : {R2_score:.3f}\n")

# %% [markdown]
# **The above Resultes show that the problem can hvar a lot of different solutions since we gonna choose the LIGHT GBM Model since it's fast and good with momery and can be deployed**

# %%
# Split the training data to train and validation

train2 , X_valid , train_y , valid_y = train_test_split(train , y_train, test_size=0.25 ,shuffle=True, random_state = 42)

X_train = tree_processer.fit_transform(train2)
X_valid = tree_processer.transform(X_valid)

# %% [markdown]
# ### Halving Gride Search

# %%
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingRandomSearchCV,HalvingGridSearchCV


Model=  LGBMRegressor(random_state=45)

# Define the parameter space
param_dist = {
    'learning_rate': [0.01,0.05,0.5],
    'num_leaves': [15, 31, 63, 127],
    'max_depth': [3,5],
    'min_child_samples': [10, 20, 50,100],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'n_estimators': [100, 200, 300,400],
    'bagging_freq':[1,2],
    'bagging_fraction':[0.50,0.75,0.85]
    
}

# Set up HalvingRandomSearchCV
halving_search = HalvingGridSearchCV(
    estimator=Model,
    param_grid=param_dist,
    factor=2,  # Halving factor
    max_resources=200,  # Maximum number of estimators to test
    random_state=42,
    scoring='r2',  # Evaluation metric
    cv=5,  # 5-fold cross-validation
    verbose=1,  # Display progress
    n_jobs=-1  # Parallelize
)


# Perform the search
halving_search.fit(X_train, train_y)

# Display the best parameters
print("Best Parameters:", halving_search.best_params_)
print("Best score:", halving_search.best_score_)
# Out:
# n_iterations: 5
# n_required_iterations: 13
# n_possible_iterations: 5
# min_resources_: 10
# max_resources_: 200
# aggressive_elimination: False
# factor: 2
# ----------
# iter: 0
# n_candidates: 6912
# n_resources: 10
# Fitting 5 folds for each of 6912 candidates, totalling 34560 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-449-97fa72f8077f> in <cell line: 35>()
#      33
#      34 # Perform the search
# ---> 35 halving_search.fit(X_train, train_y)
#      36
#      37 # Display the best parameters
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search_successive_halving.py in fit(self, X, y, groups, **fit_params)
#     271         self._n_samples_orig = _num_samples(X)
#     272
# --> 273         super().fit(X, y=y, groups=groups, **fit_params)
#     274
# ...

# %%
params = {'bagging_fraction': 0.5,
          'bagging_freq': 1,
          'colsample_bytree': 1.0, 
          'learning_rate': 0.01,
          'max_depth': 5,
          'min_child_samples': 10, 
          'n_estimators': 300,
          'num_leaves': 31}

# %% [markdown]
# ### Model Training
#
#     Using 5 Folds cross validation whith the light gbm model.

# %%
import lightgbm as lgb
from lightgbm import early_stopping
from lightgbm import log_evaluation

# dtrain = lgb.Dataset(X_train , label = train_y)
# dvalid = lgb.Dataset(X_valid , label = valid_y)

# %%
RMSE_val_scores = []
RMSE_train_scores = []

R2_val_scores = []
R2_train_scores = []

kf = KFold(n_splits=5)

for fold, (train_index, val_index) in enumerate(kf.split(train,y_train)):

    print(f"Fold {fold+1}")
    
    d_train, Y_train = train.iloc[train_index], y_train.iloc[train_index]
    d_val, Y_val = train.iloc[val_index], y_train.iloc[val_index]

    d_train = tree_processer.fit_transform(d_train)
    d_val = tree_processer.transform(d_val)
    
    dtrain = lgb.Dataset(d_train , label = Y_train)
    dvalid = lgb.Dataset(d_val , label = Y_val)

    model = lgb.train(params,
                     train_set = dtrain,
                      valid_sets=[dtrain, dvalid],
                      callbacks=[early_stopping(50), log_evaluation(50)])
    
    
    val_perd = model.predict(d_val)
    train_perd = model.predict(d_train)

    val_RMSE = np.sqrt(mean_squared_error(val_perd,Y_val))
    train_RMSE = np.sqrt(mean_squared_error(train_perd,Y_train))

    val_r2 = r2_score(val_perd,Y_val)
    train_r2 = r2_score(train_perd,Y_train)

    print(25*"--")
    
    
    print(f"Training RMSE:{train_RMSE:.3f}")
    print(f"Valsiation RMSE:{val_RMSE:.3f}")

    print(f"Training R2_score:{val_r2:.3f}")
    print(f"Training R2_scor:{val_r2:.3f}")

    print(25*"--")
    
    RMSE_val_scores.append(val_RMSE)
    RMSE_train_scores.append(train_RMSE)
    
    R2_val_scores.append(val_r2)
    R2_train_scores.append(train_r2)    
    

print(f"Cross Val RMSE: {np.mean(RMSE_val_scores):.4f}")
print(f"Cross Val RMSE train: {np.mean(RMSE_train_scores):.4f}")

print(f"Cross Val R2_score: {np.mean(R2_val_scores):.4f}")
print(f"Cross Val RMSE R2_score: {np.mean(R2_train_scores):.4f}")
# Out:
# Fold 1
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002896 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1295
# [LightGBM] [Info] Number of data points in the train set: 100828, number of used features: 28
# [LightGBM] [Info] Start training from score 200.763243
# Training until validation scores don't improve for 50 rounds
# [50]	training's l2: 5008.88	valid_1's l2: 4934.5
# [100]	training's l2: 1904.34	valid_1's l2: 1876.44
# [150]	training's l2: 729.331	valid_1's l2: 718.664
# [200]	training's l2: 279.758	valid_1's l2: 275.642
# [250]	training's l2: 109.321	valid_1's l2: 107.69
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
X_test = tree_processer.fit_transform(test)

prediction = model.predict(X_test)

print(f"RMSE: {np.sqrt(mean_squared_error(y_test,prediction))}")
print(f"RMSE: {np.sqrt(mean_absolute_error(y_test,prediction))}")
print(f"R2_score: {r2_score(y_test,prediction)}")
# Out:
# RMSE: 6.713726320298505
# RMSE: 2.2510282308825844
# R2_score: 0.9965467920756492

# %%
import matplotlib.pyplot as plt
lgb.plot_importance(model, max_num_features=20)
plt.show()

# %%
train.head()

# %% [markdown]
# ### Results Interpertaion

# %%
residuals =   y_test - prediction
plt.scatter(prediction, residuals)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residuals vs. Predicted Values")
plt.show()

# %%
plt.hist(residuals, bins=30)
plt.xlabel("Residuals")
plt.title("Residual Distribution")
plt.show()

# %%
import optuna
import lightgbm as lgb
from lightgbm import early_stopping
from lightgbm import log_evaluation

dtrain = lgb.Dataset(X_train , label = train_y)
dvalid = lgb.Dataset(X_valid , label = valid_y)


# Define objective function
def objective(trial):
    # Define hyperparameter search space
    params = {
        "objective": "regression",
        "metric": "rmse",
        "num_leaves": trial.suggest_int("num_leaves", 10, 200),
        "max_depth": trial.suggest_int("max_depth", 1, 5),
        "learning_rate": trial.suggest_loguniform("learning_rate", 1e-4, 0.1),
        "n_estimators": trial.suggest_int("n_estimators", 50, 400),
        # "min_child_samples": trial.suggest_int("min_child_samples", 5, 50),
        # "subsample": trial.suggest_uniform("subsample", 0.5, 1.0),
        # "colsample_bytree": trial.suggest_uniform("colsample_bytree", 0.5, 1.0),
        'feature_fraction': trial.suggest_uniform('feature_fraction', 0.5, 1.0),
        'bagging_fraction': trial.suggest_uniform('bagging_fraction', 0.5, 1.0),  # Include bagging_fraction
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 10),
        "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-8, 10.0),
        "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-8, 10.0),
    }
    # 'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 10, 100),
        

    # Train LightGBM model
    model = lgb.train(params,
                train_set=dtrain,
               num_boost_round=100,
               valid_sets=[dtrain, dvalid],
        callbacks=[early_stopping(100), log_evaluation(100)],
               )
    # model.fit(
    #     X_train,
    #     train_y,
    #     eval_set=[(X_valid, valid_y)],
    #     eval_metric="rmse",
    #     callbacks=[early_stopping(50), log_evaluation(50)]

    # )

    # Predict and calculate RMSE
    preds = model.predict(X_valid)
    rmse = mean_squared_error(valid_y, preds, squared=False)
    return rmse

# Create a study and optimize
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50)

# Get the best parameters
print("Best parameters:", study.best_params)
print("Best RMSE:", study.best_value)

# # Train the final model with the best parameters
# best_params = study.best_params
# final_model = lgb.LGBMRegressor(**best_params)
# final_model.fit(X, y)
# Out:
# [I 2025-01-22 00:09:10,182] A new study created in memory with name: no-name-05e983f1-dee0-492b-9a10-35dfbe095a3c
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027673 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1286
# [LightGBM] [Info] Number of data points in the train set: 94515, number of used features: 28
# [LightGBM] [Info] Start training from score 200.442770
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 100 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
Model_params = {
               'num_leaves': 92,
               'max_depth': 13,
               'learning_rate': 0.07756351400514011,
               'n_estimators': 317,
               'min_child_samples': 13,
               'subsample': 0.726684966659252, 
               'colsample_bytree': 0.9944718291866411,
               'reg_alpha': 0.42371494143583394,
               'reg_lambda': 4.228752711456665}
Model_params2 =  study.best_params

# %%
model = LGBMRegressor(**Model_params2,random_state=42)
model.fit(X_train , train_y)

pred = model.predict(X_valid)

rmse_scores = np.sqrt(mean_squared_error(pred,valid_y))
MAE_scores = mean_absolute_error(pred,valid_y)
R2_score = r2_score(pred , valid_y)

mean_absolute_error
print(f"Cross-Validation RMSE: {rmse_scores:.2f}")
print(f"Cross-Validation MAE: {MAE_scores:.2f}")
print(f"Cross-Validation R2_score : {R2_score}\n")
# Out:
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.8164964717128763, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8164964717128763
# [LightGBM] [Warning] bagging_fraction is set=0.8605561967432477, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8605561967432477
# [LightGBM] [Warning] bagging_freq is set=9, subsample_freq=0 will be ignored. Current value: bagging_freq=9
# [LightGBM] [Warning] feature_fraction is set=0.8164964717128763, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8164964717128763
# [LightGBM] [Warning] bagging_fraction is set=0.8605561967432477, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8605561967432477
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002785 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# ...

# %%
import matplotlib.pyplot as plt

residuals =   valid_y - pred
plt.scatter(valid_y, residuals)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residuals vs. Predicted Values")
plt.show()

# %%
plt.hist(residuals, bins=30)
plt.xlabel("Residuals")
plt.title("Residual Distribution")
plt.show()

# %%
importances = model.feature_importances_
plt.bar(range(len(importances)), importances)
plt.title("Feature Importances")
plt.show()

# %%
scores = []
kf = KFold(n_splits=5)

for train_index, val_index in kf.split(train,y_train):
    
    X_train, Y_train = train.iloc[train_index], y_train.iloc[train_index]
    X_val, y_val = train.iloc[val_index], y_train.iloc[val_index]
    
    X_train = preprocessor.fit_transform(X_train)
    X_val = preprocessor.transform(X_val)
    xg = XGBRegressor(**Model params, random_state=42)
    xg.fit(X_train,Y_train)
    y_pred = xg.predict(X_val)
    
    scores.append(np.sqrt(mean_squared_error(y_pred,y_val)))
    
    print(np.sqrt(mean_squared_error(y_pred,y_val)))
    print(np.sqrt(mean_squared_error(y_pred,y_val)))
    print(np.sqrt(mean_squared_error(y_pred,y_val)))
    

print("Cross Val RMSE:",np.mean(scores))

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### features selection

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# Train Lasso model
lasso = Lasso(alpha=0.02)
lasso.fit(train, y_train)

# Select features
sfm = SelectFromModel(lasso, prefit=True)
X_new = sfm.transform(train)

# Get selected features
selected_features = train.columns[sfm.get_support()]
print(selected_features)

# %%
train = train[selected_features.to_list()]
train.head()

# %% [markdown]
# ## Model Training

# %%
scores = []
kf = KFold(n_splits=5)

for train_index, val_index in kf.split(train,y_train):
    
    X_train, Y_train = train.iloc[train_index], y_train.iloc[train_index]
    X_val, y_val = train.iloc[val_index], y_train.iloc[val_index]
    
    X_train = preprocessor.fit_transform(X_train)
    X_val = preprocessor.transform(X_val)
    xg = XGBRegressor(objective="reg:squarederror", random_state=42)
    xg.fit(X_train,Y_train)
    y_pred = xg.predict(X_val)
    
    scores.append(np.sqrt(mean_squared_error(y_pred,y_val)))
    
    print(np.sqrt(mean_squared_error(y_pred,y_val)))
    print(np.sqrt(mean_squared_error(y_pred,y_val)))
    print(np.sqrt(mean_squared_error(y_pred,y_val)))
    

print("Cross Val RMSE:",np.mean(scores))

# %%
#Plot the LGBM Features Importances
def plotImp(model, X , num = 20, fig_size = (40, 20)):
    feature_imp = pd.DataFrame({'Value':model.feature_importances_,'Feature':X.columns})
    plt.figure(figsize=fig_size)
    sns.set(font_scale = 5)
    sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value", 
                                                        ascending=False)[0:num])
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout()
    plt.savefig('lgbm_importances-01.png')
    plt.show()

# %%
train = preprocessor.fit_transform(train)

# %%
gbm = LGBMRegressor(max_depth=5,n_estimators=200,random_state=45,learning_rate=0.5)

gbm.fit(train,y_train)
plotImp(gbm,train)
